# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
#import warnings
#warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_df = pd.read_csv("Data/mouse_drug_data.csv")
clinical_trial_df = pd.read_csv("Data/clinicaltrial_data.csv")

# Read the Mouse and Drug Data and the Clinical Trial Data


# Combine the data into a single dataset


# Display the data table for preview

# %%
mouse_drug_df.head()
# Out:
#   Mouse ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn

# %%
mouse_drug_df.describe
# Out:
# <bound method NDFrame.describe of     Mouse ID      Drug
# 0       f234  Stelasyn
# 1       x402  Stelasyn
# 2       a492  Stelasyn
# 3       w540  Stelasyn
# 4       v764  Stelasyn
# 5       o848  Stelasyn
# 6       z314  Stelasyn
# 7       g989  Stelasyn
# 8       m269  Stelasyn
# 9       a963  Stelasyn
# 10      t451  Stelasyn
# 11      p981  Stelasyn
# 12      k510  Stelasyn
# 13      h333  Stelasyn
# 14      c402  Stelasyn
# 15      j984  Stelasyn
# 16      w697  Stelasyn
# 17      s619  Stelasyn
# 18      g867  Stelasyn
# 19      k862  Stelasyn
# 20      i901  Stelasyn
# 21      b879  Stelasyn
# 22      p387  Stelasyn
# 23      a366  Stelasyn
# 24      s565  Stelasyn
# 25      j755  Naftisol
# 26      e213  Naftisol
# 27      e584  Naftisol
# 28      e291  Naftisol
# 29      z795  Naftisol
# ..       ...       ...
# 220     a444  Ramicane
# 221     a411  Ramicane
# 222     j913  Ramicane
# 223     q610  Ramicane
# 224     c458  Ramicane
# 225     a897   Placebo
# 226     c757   Placebo
# 227     i477   Placebo
# 228     o302   Placebo
# 229     t718   Placebo
# 230     w167   Placebo
# 231     x773   Placebo
# 232     s166   Placebo
# 233     q582   Placebo
# 234     y478   Placebo
# 235     o795   Placebo
# 236     l872   Placebo
# 237     t994   Placebo
# 238     v409   Placebo
# 239     v989   Placebo
# 240     c282   Placebo
# 241     e227   Placebo
# 242     c766   Placebo
# 243     s152   Placebo
# 244     n763   Placebo
# 245     i669   Placebo
# 246     r850   Placebo
# 247     a262   Placebo
# 248     q787   Placebo
# 249     j235   Placebo
#
# [250 rows x 2 columns]>

# %%
print(len(mouse_drug_df["Mouse ID"].unique()))

# This shows that there are no duplicates in the Mouse ID column of my
# right dataframe.
# Out:
# 249

# %%
print(len(clinical_trial_df["Mouse ID"].unique()))
# Out:
# 249

# %%
# Remove any duplicates from the mouse dataset and check to make sure
# each unique mouse ID is still represented
mouse_drug_no_duplicates_df = mouse_drug_df.drop_duplicates(subset="Mouse ID")
print(len(mouse_drug_no_duplicates_df["Mouse ID"].unique()))
# Out:
# 249

# %%
clinical_trial_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
clinical_trial_df.describe
# Out:
# <bound method NDFrame.describe of      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# 5        h246          0           45.000000                 0
# 6        p189          0           45.000000                 0
# 7        n923          0           45.000000                 0
# 8        q119          0           45.000000                 0
# 9        f993          0           45.000000                 0
# 10       z234          0           45.000000                 0
# 11       b559          0           45.000000                 0
# 12       y260          0           45.000000                 0
# 13       x930          0           45.000000                 0
# 14       o725          0           45.000000                 0
# 15       z969          0           45.000000                 0
# 16       v835          0           45.000000                 0
# 17       r604          0           45.000000                 0
# 18       n304          0           45.000000                 0
# 19       l700          0           45.000000                 0
# 20       x336          0           45.000000                 0
# 21       l725          0           45.000000                 0
# 22       m133          0           45.000000                 0
# 23       v295          0           45.000000                 0
# 24       a818          0           45.000000                 0
# 25       y601          0           45.000000                 0
# 26       t724          0           45.000000                 0
# 27       k382          0           45.000000                 0
# 28       w422          0           45.000000                 0
# 29       c326          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1863     l700         45           63.946640                 1
# 1864     l733         45           64.299830                 1
# 1865     n304         45           63.586395                 4
# 1866     o795         45           73.059454                 4
# 1867     u196         45           40.667713                 3
# 1868     r604         45           62.670759                 3
# 1869     z969         45           73.867845                 4
# 1870     g791         45           29.128472                 1
# 1871     i635         45           58.633404                 3
# 1872     o287         45           59.741901                 4
# 1873     r701         45           69.778544                 1
# 1874     r811         45           37.225650                 1
# 1875     u327         45           66.268801                 2
# 1876     s565         45           72.588964                 2
# 1877     g570         45           70.492788                 2
# 1878     i557         45           47.685963                 1
# 1879     a644         45           32.978522                 1
# 1880     j755         45           69.563621                 1
# 1881     e213         45           63.105696                 4
# 1882     e584         45           68.359777                 4
# 1883     t718         45           63.423695                 4
# 1884     o562         45           72.455421                 2
# 1885     i177         45           33.562402                 3
# 1886     v991         45           70.167749                 4
# 1887     z795         45           65.741070                 3
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]>

# %%
merged_mouse_data_df = pd.merge(clinical_trial_df,
                               mouse_drug_no_duplicates_df, 
                                on="Mouse ID",
                               how="left")
merged_mouse_data_df.describe
# Out:
# <bound method NDFrame.describe of      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0        b128          0           45.000000                 0  Capomulin
# 1        f932          0           45.000000                 0   Ketapril
# 2        g107          0           45.000000                 0   Ketapril
# 3        a457          0           45.000000                 0   Ketapril
# 4        c819          0           45.000000                 0   Ketapril
# 5        h246          0           45.000000                 0   Ketapril
# 6        p189          0           45.000000                 0   Ketapril
# 7        n923          0           45.000000                 0   Ketapril
# 8        q119          0           45.000000                 0   Ketapril
# 9        f993          0           45.000000                 0   Naftisol
# 10       z234          0           45.000000                 0   Naftisol
# 11       b559          0           45.000000                 0   Naftisol
# 12       y260          0           45.000000                 0   Ketapril
# 13       x930          0           45.000000                 0   Naftisol
# 14       o725          0           45.000000                 0   Naftisol
# 15       z969          0           45.000000                 0   Naftisol
# 16       v835          0           45.000000                 0   Naftisol
# 17       r604          0           45.000000                 0   Naftisol
# 18       n304          0           45.000000                 0   Naftisol
# 19       l700          0           45.000000                 0   Naftisol
# 20       x336          0           45.000000                 0   Naftisol
# 21       l725          0           45.000000                 0   Naftisol
# 22       m133          0           45.000000                 0   Naftisol
# 23       v295          0           45.000000                 0   Naftisol
# 24       a818          0           45.000000                 0   Naftisol
# 25       y601          0           45.000000                 0   Naftisol
# 26       t724          0           45.000000                 0   Naftisol
# 27       k382          0           45.000000                 0   Ketapril
# 28       w422          0           45.000000                 0   Ketapril
# 29       c326          0           45.000000                 0  Infubinol
# ...       ...        ...                 ...               ...        ...
# 1863     l700         45           63.946640                 1   Naftisol
# 1864     l733         45           64.299830                 1   Ceftamin
# 1865     n304         45           63.586395                 4   Naftisol
# 1866     o795         45           73.059454                 4    Placebo
# 1867     u196         45           40.667713                 3   Ramicane
# 1868     r604         45           62.670759                 3   Naftisol
# 1869     z969         45           73.867845                 4   Naftisol
# 1870     g791         45           29.128472                 1   Ramicane
# 1871     i635         45           58.633404                 3   Propriva
# 1872     o287         45           59.741901                 4   Ceftamin
# 1873     r701         45           69.778544                 1   Naftisol
# 1874     r811         45           37.225650                 1   Ramicane
# 1875     u327         45           66.268801                 2   Ketapril
# 1876     s565         45           72.588964                 2   Stelasyn
# 1877     g570         45           70.492788                 2   Propriva
# 1878     i557         45           47.685963                 1  Capomulin
# 1879     a644         45           32.978522                 1   Ramicane
# 1880     j755         45           69.563621                 1   Naftisol
# 1881     e213         45           63.105696                 4   Naftisol
# 1882     e584         45           68.359777                 4   Naftisol
# 1883     t718         45           63.423695                 4    Placebo
# 1884     o562         45           72.455421                 2   Propriva
# 1885     i177         45           33.562402                 3   Ramicane
# 1886     v991         45           70.167749                 4   Propriva
# 1887     z795         45           65.741070                 3   Naftisol
# 1888     r944         45           41.581521                 2  Capomulin
# 1889     u364         45           31.023923                 3  Capomulin
# 1890     p438         45           61.433892                 1   Ceftamin
# 1891     x773         45           58.634971                 4    Placebo
# 1892     b879         45           72.555239                 2   Stelasyn
#
# [1893 rows x 5 columns]>

# %%
merged_mouse_data_df.dropna(how="any")
merged_mouse_data_df.describe
# Out:
# <bound method NDFrame.describe of      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0        b128          0           45.000000                 0  Capomulin
# 1        f932          0           45.000000                 0   Ketapril
# 2        g107          0           45.000000                 0   Ketapril
# 3        a457          0           45.000000                 0   Ketapril
# 4        c819          0           45.000000                 0   Ketapril
# 5        h246          0           45.000000                 0   Ketapril
# 6        p189          0           45.000000                 0   Ketapril
# 7        n923          0           45.000000                 0   Ketapril
# 8        q119          0           45.000000                 0   Ketapril
# 9        f993          0           45.000000                 0   Naftisol
# 10       z234          0           45.000000                 0   Naftisol
# 11       b559          0           45.000000                 0   Naftisol
# 12       y260          0           45.000000                 0   Ketapril
# 13       x930          0           45.000000                 0   Naftisol
# 14       o725          0           45.000000                 0   Naftisol
# 15       z969          0           45.000000                 0   Naftisol
# 16       v835          0           45.000000                 0   Naftisol
# 17       r604          0           45.000000                 0   Naftisol
# 18       n304          0           45.000000                 0   Naftisol
# 19       l700          0           45.000000                 0   Naftisol
# 20       x336          0           45.000000                 0   Naftisol
# 21       l725          0           45.000000                 0   Naftisol
# 22       m133          0           45.000000                 0   Naftisol
# 23       v295          0           45.000000                 0   Naftisol
# 24       a818          0           45.000000                 0   Naftisol
# 25       y601          0           45.000000                 0   Naftisol
# 26       t724          0           45.000000                 0   Naftisol
# 27       k382          0           45.000000                 0   Ketapril
# 28       w422          0           45.000000                 0   Ketapril
# 29       c326          0           45.000000                 0  Infubinol
# ...       ...        ...                 ...               ...        ...
# 1863     l700         45           63.946640                 1   Naftisol
# 1864     l733         45           64.299830                 1   Ceftamin
# 1865     n304         45           63.586395                 4   Naftisol
# 1866     o795         45           73.059454                 4    Placebo
# 1867     u196         45           40.667713                 3   Ramicane
# 1868     r604         45           62.670759                 3   Naftisol
# 1869     z969         45           73.867845                 4   Naftisol
# 1870     g791         45           29.128472                 1   Ramicane
# 1871     i635         45           58.633404                 3   Propriva
# 1872     o287         45           59.741901                 4   Ceftamin
# 1873     r701         45           69.778544                 1   Naftisol
# 1874     r811         45           37.225650                 1   Ramicane
# 1875     u327         45           66.268801                 2   Ketapril
# 1876     s565         45           72.588964                 2   Stelasyn
# 1877     g570         45           70.492788                 2   Propriva
# 1878     i557         45           47.685963                 1  Capomulin
# 1879     a644         45           32.978522                 1   Ramicane
# 1880     j755         45           69.563621                 1   Naftisol
# 1881     e213         45           63.105696                 4   Naftisol
# 1882     e584         45           68.359777                 4   Naftisol
# 1883     t718         45           63.423695                 4    Placebo
# 1884     o562         45           72.455421                 2   Propriva
# 1885     i177         45           33.562402                 3   Ramicane
# 1886     v991         45           70.167749                 4   Propriva
# 1887     z795         45           65.741070                 3   Naftisol
# 1888     r944         45           41.581521                 2  Capomulin
# 1889     u364         45           31.023923                 3  Capomulin
# 1890     p438         45           61.433892                 1   Ceftamin
# 1891     x773         45           58.634971                 4    Placebo
# 1892     b879         45           72.555239                 2   Stelasyn
#
# [1893 rows x 5 columns]>

# %%
merged_mouse_data_df.head(10)
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0                45.0                 0  Capomulin
# 1     f932          0                45.0                 0   Ketapril
# 2     g107          0                45.0                 0   Ketapril
# 3     a457          0                45.0                 0   Ketapril
# 4     c819          0                45.0                 0   Ketapril
# 5     h246          0                45.0                 0   Ketapril
# 6     p189          0                45.0                 0   Ketapril
# 7     n923          0                45.0                 0   Ketapril
# 8     q119          0                45.0                 0   Ketapril
# 9     f993          0                45.0                 0   Naftisol

# %%
merged_mouse_data_df["Metastatic Sites"].value_counts()
# Out:
# 0    793
# 1    590
# 2    274
# 3    148
# 4     88
# Name: Metastatic Sites, dtype: int64

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
# Group by drug and timepoint

merged_grouped_by_drug_and_timepoint= merged_mouse_data_df.groupby([
    "Drug",
    "Timepoint"
])

# Get mean tumor size for each time point for each drug

tumor_response_series = merged_grouped_by_drug_and_timepoint["Tumor Volume (mm3)"].mean()
tumor_response_series
# Out:
# Drug       Timepoint
# Capomulin  0            45.000000
#            5            44.266086
#            10           43.084291
#            15           42.064317
#            20           40.716325
#            25           39.939528
#            30           38.769339
#            35           37.816839
#            40           36.958001
#            45           36.236114
# Ceftamin   0            45.000000
#            5            46.503051
#            10           48.285125
#            15           50.094055
#            20           52.157049
#            25           54.287674
#            30           56.769517
#            35           58.827548
#            40           61.467895
#            45           64.132421
# Infubinol  0            45.000000
#            5            47.062001
#            10           49.403909
#            15           51.296397
#            20           53.197691
#            25           55.715252
#            30           58.299397
#            35           60.742461
#            40           63.162824
#            45           65.755562
#                           ...
# Ramicane   0            45.000000
#            5            43.944859
#            10           42.531957
#            15           41.495061
#            20           40.238325
#            25           38.974300
#            30           38.703137
#            35           37.451996
#            40           36.574081
#            45           34.955595
# Stelasyn   0            45.000000
#            5            47.527452
#            10           49.463844
#            15           51.529409
#            20           54.067395
#            25           56.166123
#            30           59.826738
#            35           62.440699
#            40           65.356386
#            45           68.438310
# Zoniferol  0            45.000000
#            5            46.851818
#            10           48.689881
#            15           50.779059
#            20           53.170334
#            25           55.432935
#            30           57.713531
#            35           60.089372
#            40           62.916692
#            45           65.960888
# Name: Tumor Volume (mm3), Length: 100, dtype: float64

# %%
tumor_response_df = pd.DataFrame(tumor_response_series)
tumor_response_df.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325

# %%
# Reset the index to return Drug and Timepoint as columns and rename column

tumor_response_df.reset_index(inplace=True)
tumor_response_df.rename(columns= {"Tumor Volume (mm3)": "Tumor Mean Volume (mm3)"}, inplace = True)
tumor_response_df.head()
# Out:
#         Drug  Timepoint  Tumor Mean Volume (mm3)
# 0  Capomulin          0                45.000000
# 1  Capomulin          5                44.266086
# 2  Capomulin         10                43.084291
# 3  Capomulin         15                42.064317
# 4  Capomulin         20                40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
tumor_volume_se_by_drug_and_timepoint_series = merged_grouped_by_drug_and_timepoint["Tumor Volume (mm3)"].sem()
# Convert to DataFrame
tumor_se_df = pd.DataFrame(tumor_volume_se_by_drug_and_timepoint_series)
tumor_se_df.reset_index(inplace = True)

# Rename Column
tumor_se_df.rename(columns = {"Tumor Volume (mm3)": "Tumor Volume SE"}, inplace = True)
# Preview DataFrame
tumor_se_df.head()
# Out:
#         Drug  Timepoint  Tumor Volume SE
# 0  Capomulin          0         0.000000
# 1  Capomulin          5         0.448593
# 2  Capomulin         10         0.702684
# 3  Capomulin         15         0.838617
# 4  Capomulin         20         0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames

long_tumor_response_df = tumor_response_df.pivot(index="Timepoint", columns = "Drug", values="Tumor Mean Volume (mm3)")
long_tumor_response_df.reset_index(inplace=True)
long_tumor_response_df.head()
# Also note that the example graphs are line graphs, not scatter plots. I can
# add error bars to the means, not to the individual points...
# I should graph ALL tumor volumes for each drug at each timepoint?

# Preview that Reformatting worked
# Out:
# Drug  Timepoint  Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol  \
# 0             0  45.000000  45.000000  45.000000  45.000000  45.000000
# 1             5  44.266086  46.503051  47.062001  47.389175  46.796098
# 2            10  43.084291  48.285125  49.403909  49.582269  48.694210
# 3            15  42.064317  50.094055  51.296397  52.399974  50.933018
# 4            20  40.716325  52.157049  53.197691  54.920935  53.644087
#
# Drug    Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# 0     45.000000  45.000000  45.000000  45.000000  45.000000
# 1     47.125589  47.168130  43.944859  47.527452  46.851818
# 2     49.423329  48.938560  42.531957  49.463844  48.689881
# 3     51.359742  50.891769  41.495061  51.529409  50.779059
# 4     54.364417  53.127384  40.238325  54.067395  53.170334

# %%
long_tumor_se_df = tumor_se_df.pivot(index="Timepoint", columns = "Drug", values="Tumor Volume SE")
long_tumor_se_df.reset_index(inplace=True)
long_tumor_se_df.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# 0             0   0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 1             5   0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 2            10   0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 3            15   0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 4            20   0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
#
# Drug  Propriva  Ramicane  Stelasyn  Zoniferol
# 0     0.000000  0.000000  0.000000   0.000000
# 1     0.241842  0.482955  0.239862   0.188950
# 2     0.388701  0.720225  0.433678   0.263949
# 3     0.502024  0.770432  0.493261   0.370544
# 4     0.607412  0.786199  0.621889   0.533182

# %%
x_axis = long_tumor_response_df["Timepoint"]
capomulin_mean = long_tumor_response_df["Capomulin"]
infubinol_mean = long_tumor_response_df["Infubinol"]
ketapril_mean = long_tumor_response_df["Ketapril"]
placebo_mean = long_tumor_response_df["Placebo"]

capomulin_se = long_tumor_se_df["Capomulin"]
infubinol_se = long_tumor_se_df["Infubinol"]
ketapril_se = long_tumor_se_df["Ketapril"]
placebo_se = long_tumor_se_df["Placebo"]

# %%
# Generate the Plot (with Error Bars)

fig, ax = plt.subplots()

#capomulin_plot, = ax.plot(x_axis, capomulin_mean, label="Capomulin")
#infubinol_plot, = ax.plot(x_axis, infubinol_mean, label = "Infubinol")
#ketapril_plot, = ax.plot(x_axis, ketapril_mean, label="Ketapril")
#placebo_plot, = ax.plot(x_axis, placebo_mean, label="Placebo")


ax.errorbar(x_axis, capomulin_mean, capomulin_se, label="Capomulin")
ax.errorbar(x_axis, infubinol_mean, infubinol_se, label="Infubinol")
ax.errorbar(x_axis, ketapril_mean, ketapril_se, label="Ketapril")
ax.errorbar(x_axis, placebo_mean, placebo_se, label="Placebo")
plt.legend(loc="best")

ax.set_ylabel("Tumor Volume (mm3)")
ax.set_xlabel("Days")
fig.suptitle("Mean Tumor Volume Change Over Time")
# Save the Figure
# Out:
# Text(0.5, 0.98, 'Mean Tumor Volume Change Over Time')

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
metastatic_group = merged_mouse_data_df["Metastatic Sites"].groupby([merged_mouse_data_df["Drug"], merged_mouse_data_df["Timepoint"]])
# Convert to DataFrame
metastatic_df = pd.DataFrame(metastatic_group.mean())
# Preview DataFrame
metastatic_df.reset_index(inplace=True)
metastatic_df = metastatic_df.rename(columns={
    "Metastatic Sites": "Mean Metastatic Sites"
})
metastatic_df.head()
# Out:
#         Drug  Timepoint  Mean Metastatic Sites
# 0  Capomulin          0               0.000000
# 1  Capomulin          5               0.160000
# 2  Capomulin         10               0.320000
# 3  Capomulin         15               0.375000
# 4  Capomulin         20               0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
metastatic_se_df = pd.DataFrame(metastatic_group.sem())

metastatic_se_df = metastatic_se_df.rename(columns = {
    "Metastatic Sites": "Metastatic SE"
})
metastatic_se_df.reset_index(inplace=True)
# Preview DataFrame
metastatic_se_df.head()
# Out:
#         Drug  Timepoint  Metastatic SE
# 0  Capomulin          0       0.000000
# 1  Capomulin          5       0.074833
# 2  Capomulin         10       0.125433
# 3  Capomulin         15       0.132048
# 4  Capomulin         20       0.161621

# %%
# metastatic_se_df["Metastatic SE"].value_counts()

# %%
# Minor Data Munging to Re-Format the Data Frames
long_metastatic_df = metastatic_df.pivot(index= "Timepoint", columns= "Drug", values= "Mean Metastatic Sites")
long_metastatic_df.reset_index(inplace=True)
# Preview that Reformatting worked
long_metastatic_df.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# 0             0   0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 1             5   0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 2            10   0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 3            15   0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 4            20   0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug  Propriva  Ramicane  Stelasyn  Zoniferol
# 0     0.000000  0.000000  0.000000   0.000000
# 1     0.347826  0.120000  0.240000   0.166667
# 2     0.619048  0.250000  0.478261   0.500000
# 3     0.800000  0.333333  0.782609   0.809524
# 4     1.000000  0.347826  0.952381   1.294118

# %%
long_metastatic_se_df = metastatic_se_df.pivot(index="Timepoint", columns= "Drug", values= "Metastatic SE")
long_metastatic_se_df.reset_index(inplace=True)
long_metastatic_se_df.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# 0             0   0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 1             5   0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 2            10   0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 3            15   0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 4            20   0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
#
# Drug  Propriva  Ramicane  Stelasyn  Zoniferol
# 0     0.000000  0.000000  0.000000   0.000000
# 1     0.101543  0.066332  0.087178   0.077709
# 2     0.108588  0.090289  0.123672   0.109109
# 3     0.144749  0.115261  0.153439   0.111677
# 4     0.195180  0.119430  0.200905   0.166378

# %%
met_capomulin_mean = long_metastatic_df["Capomulin"]
met_infubinol_mean = long_metastatic_df["Infubinol"]
met_ketapril_mean = long_metastatic_df["Ketapril"]
met_placebo_mean = long_metastatic_df["Placebo"]

met_capomulin_se = long_metastatic_se_df["Capomulin"]
met_infubinol_se = long_metastatic_se_df["Infubinol"]
met_ketapril_se = long_metastatic_se_df["Ketapril"]
met_placebo_se = long_metastatic_se_df["Placebo"]

# %%
met_capomulin_mean
# Out:
# 0    0.000000
# 1    0.160000
# 2    0.320000
# 3    0.375000
# 4    0.652174
# 5    0.818182
# 6    1.090909
# 7    1.181818
# 8    1.380952
# 9    1.476190
# Name: Capomulin, dtype: float64

# %%
# Generate the Plot (with Error Bars)

fig, ax = plt.subplots()

ax.errorbar(x_axis, met_capomulin_mean, met_capomulin_se, label="Capomulin")
ax.errorbar(x_axis, met_infubinol_mean, met_infubinol_se, label="Infubinol")
ax.errorbar(x_axis, met_ketapril_mean, met_ketapril_se, label="Ketapril")
ax.errorbar(x_axis, met_placebo_mean, met_placebo_se, label="Placebo")
plt.legend(loc="best")

ax.set_ylabel("Number of Metastatic Sites")
ax.set_xlabel("Days")
fig.suptitle("Mean Change in Metastatic Sites Over Time")
# Save the Figure

# Show the Figure
# Out:
# Text(0.5, 0.98, 'Mean Change in Metastatic Sites Over Time')

# %% [markdown]
# ## Survival Rates

# %%
merged_mouse_data_df["Timepoint"].value_counts()
# Out:
# 0     250
# 5     238
# 10    223
# 15    207
# 20    195
# 25    183
# 30    171
# 35    154
# 40    142
# 45    130
# Name: Timepoint, dtype: int64

# %%
mortality_group = merged_mouse_data_df.groupby([merged_mouse_data_df["Drug"], merged_mouse_data_df["Timepoint"]])
mortality_df = pd.DataFrame(mortality_group.count())
mortality_df.reset_index(inplace=True)
mortality_df = mortality_df[["Drug", "Timepoint", "Mouse ID"]]
mortality_df = mortality_df.rename(columns={
    "Mouse ID": "Mouse Count"
})
mortality_df.head()
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame

# Preview DataFrame

# %%
long_mortality_df = mortality_df.pivot(index="Timepoint", columns= "Drug", values="Mouse Count")
long_mortality_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                24        25        26         25
# 5                23        25        25         24
# 10               21        24        23         22
# 15               15        24        23         21
# 20               15        23        21         17
# 25               13        23        19         16
# 30               12        23        18         15
# 35                9        21        16         14
# 40                9        20        12         14
# 45                7        20        11         14

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
# Generate the Plot (Accounting for percentages)
fig, ax = plt.subplots()



# Save the Figure

# Show the Figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-f27c7c0f9685> in <module>
#       1 # Generate the Plot (Accounting for percentages)
# ----> 2 fig, ax = plt.subplot()
#       3 # Save the Figure
#       4
#       5 # Show the Figure
#
# TypeError: cannot unpack non-iterable AxesSubplot object

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()
